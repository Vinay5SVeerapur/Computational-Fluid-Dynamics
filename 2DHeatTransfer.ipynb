# %%
gama=1000
area=10
x=10
n1=0
n2=0
n3=0

s1=0
s2=0
s3=0

w1=450
w2=450
w3=450

e1=0
e2=0
e3=0
import numpy as np
from numpy.linalg import inv
matrix=np.zeros((9,9))

#1
matrix[0,0]=(6*gama*area/x)
matrix[0,1]=-(gama*area/x)
matrix[0,2]=0
matrix[0,3]=-(gama*area/x)
matrix[0,4]=0
matrix[0,5]=0
matrix[0,6]=0
matrix[0,7]=0
matrix[0,8]=0

#2
matrix[1,0]=0
matrix[1,1]=0
matrix[1,2]=0
matrix[1,3]=-(gama*area/x)
matrix[1,4]=0
matrix[1,5]=0
matrix[1,6]=6*gama*area/x
matrix[1,7]=-(gama*area/x)
matrix[1,8]=0

#3
matrix[2,0]=0
matrix[2,1]=-(gama*area/x)
matrix[2,2]=6*gama*area/x
matrix[2,3]=0
matrix[2,4]=0
matrix[2,5]=-(gama*area/x)
matrix[2,6]=0
matrix[2,7]=0
matrix[2,8]=0

#4
matrix[3,0]=0
matrix[3,1]=0
matrix[3,2]=0
matrix[3,3]=0
matrix[3,4]=0
matrix[3,5]=-(gama*area/x)
matrix[3,6]=0
matrix[3,7]=-gama*area/x
matrix[3,8]=(6*gama*area/x)

#5
matrix[4,0]=-gama*area/x
matrix[4,1]=5*gama*area/x
matrix[4,2]=-gama*area/x
matrix[4,3]=0
matrix[4,4]=0
matrix[4,5]=0
matrix[4,6]=0
matrix[4,7]=0
matrix[4,8]=0

#6
matrix[5,0]=-gama*area/x
matrix[5,1]=0
matrix[5,2]=0
matrix[5,3]=5*gama*area/x
matrix[5,4]=-gama*area/x
matrix[5,5]=0
matrix[5,6]=-gama*area/x
matrix[5,7]=0
matrix[5,8]=0

#7
matrix[6,0]=0
matrix[6,1]=0
matrix[6,2]=-gama*area/x
matrix[6,3]=0
matrix[6,4]=-gama*area/x
matrix[6,5]=5*gama*area/x
matrix[6,6]=0
matrix[6,7]=0
matrix[6,8]=-gama*area/x

#8
matrix[7,0]=0
matrix[7,1]=0
matrix[7,2]=0
matrix[7,3]=0
matrix[7,4]=-1*gama*area/x
matrix[7,5]=0
matrix[7,6]=-1*gama*area/x
matrix[7,7]=5*gama*area/x
matrix[7,8]=-1*gama*area/x

#9
matrix[8,0]=0
matrix[8,1]=-1*gama*area/x
matrix[8,2]=0
matrix[8,3]=-1*gama*area/x
matrix[8,4]=4*gama*area/x
matrix[8,5]=-1*gama*area/x
matrix[8,6]=0
matrix[8,7]=-1*gama*area/x
matrix[8,8]=0

#print(matrix)
b=np.zeros((9,1))

b[0,0]=(4*gama*area/x)*(w1+n1)
b[1,0]=(4*gama*area/x)*(w3+s1)
b[2,0]=(4*gama*area/x)*(e1+n3)
b[3,0]=(4*gama*area/x)*(e3+s3)
b[4,0]=2*(gama*area/x)*(n2)
b[5,0]=(2*gama*area/x)*w2
b[6,0]=(2*gama*area/x)*e2
b[7,0]=(2*gama*area/x)*s2
b[8,0]=(0)

#print(b)
sol=np.dot(inv(matrix),b)
print(sol)
print(matrix)
import matplotlib.pyplot as plt
plt.plot(sol[0:3])
plt.plot(sol[3:6])
plt.plot(sol[6:])
# Out:
# [[373.00664452]
#  [ 78.48837209]
#  [ 19.43521595]
#  [359.55149502]
#  [146.51162791]
#  [ 38.12292359]
#  [378.23920266]
#  [109.88372093]
#  [ 24.66777409]]
# [[ 6000. -1000.     0. -1000.     0.     0.     0.     0.     0.]
#  [    0.     0.     0. -1000.     0.     0.  6000. -1000.     0.]
#  [    0. -1000.  6000.     0.     0. -1000.     0.     0.     0.]
#  [    0.     0.     0.     0.     0. -1000.     0. -1000.  6000.]
#  [-1000.  5000. -1000.     0.     0.     0.     0.     0.     0.]
#  [-1000.     0.     0.  5000. -1000.     0. -1000.     0.     0.]
#  [    0.     0. -1000.     0. -1000.  5000.     0.     0. -1000.]
#  [    0.     0.     0.     0. -1000.     0. -1000.  5000. -1000.]
#  [    0. -1000.     0. -1000.  4000. -1000.     0. -1000.     0.]]

# %% [markdown]
# Making the matrix bigger

# %%
gama=1000
area=10
x=10
n1=0
n2=0
n3=0

s1=0
s2=0
s3=0

w1=450
w2=450
w3=450

e1=0
e2=0
e3=0
import numpy as np
from numpy.linalg import inv
matrix=np.zeros((9,9))

#1
matrix[0,0]=(6*gama*area/x)
matrix[0,1]=-(gama*area/x)
matrix[0,2]=0
matrix[0,3]=-(gama*area/x)
matrix[0,4]=0
matrix[0,5]=0
matrix[0,6]=0
matrix[0,7]=0
matrix[0,8]=0

#2
matrix[1,0]=0
matrix[1,1]=0
matrix[1,2]=0
matrix[1,3]=-(gama*area/x)
matrix[1,4]=0
matrix[1,5]=0
matrix[1,6]=6*gama*area/x
matrix[1,7]=-(gama*area/x)
matrix[1,8]=0

#3
matrix[2,0]=0
matrix[2,1]=-(gama*area/x)
matrix[2,2]=6*gama*area/x
matrix[2,3]=0
matrix[2,4]=0
matrix[2,5]=-(gama*area/x)
matrix[2,6]=0
matrix[2,7]=0
matrix[2,8]=0

#4
matrix[3,0]=0
matrix[3,1]=0
matrix[3,2]=0
matrix[3,3]=0
matrix[3,4]=0
matrix[3,5]=-(gama*area/x)
matrix[3,6]=0
matrix[3,7]=-gama*area/x
matrix[3,8]=(6*gama*area/x)

#5
matrix[4,0]=-gama*area/x
matrix[4,1]=5*gama*area/x
matrix[4,2]=-gama*area/x
matrix[4,3]=0
matrix[4,4]=0
matrix[4,5]=0
matrix[4,6]=0
matrix[4,7]=0
matrix[4,8]=0

#6
matrix[5,0]=-gama*area/x
matrix[5,1]=0
matrix[5,2]=0
matrix[5,3]=5*gama*area/x
matrix[5,4]=-gama*area/x
matrix[5,5]=0
matrix[5,6]=-gama*area/x
matrix[5,7]=0
matrix[5,8]=0

#7
matrix[6,0]=0
matrix[6,1]=0
matrix[6,2]=-gama*area/x
matrix[6,3]=0
matrix[6,4]=-gama*area/x
matrix[6,5]=5*gama*area/x
matrix[6,6]=0
matrix[6,7]=0
matrix[6,8]=-gama*area/x

#8
matrix[7,0]=0
matrix[7,1]=0
matrix[7,2]=0
matrix[7,3]=0
matrix[7,4]=-1*gama*area/x
matrix[7,5]=0
matrix[7,6]=-1*gama*area/x
matrix[7,7]=5*gama*area/x
matrix[7,8]=-1*gama*area/x

#9
matrix[8,0]=0
matrix[8,1]=-1*gama*area/x
matrix[8,2]=0
matrix[8,3]=-1*gama*area/x
matrix[8,4]=4*gama*area/x
matrix[8,5]=-1*gama*area/x
matrix[8,6]=0
matrix[8,7]=-1*gama*area/x
matrix[8,8]=0

#print(matrix)
b=np.zeros((9,1))

b[0,0]=(4*gama*area/x)*(w1+n1)
b[1,0]=(4*gama*area/x)*(w3+s1)
b[2,0]=(4*gama*area/x)*(e1+n3)
b[3,0]=(4*gama*area/x)*(e3+s3)
b[4,0]=2*(gama*area/x)*(n2)
b[5,0]=(2*gama*area/x)*w2
b[6,0]=(2*gama*area/x)*e2
b[7,0]=(2*gama*area/x)*s2
b[8,0]=(0)

#print(b)
sol=np.dot(inv(matrix),b)
print(sol)
print(matrix)
import matplotlib.pyplot as plt
plt.plot(sol[0:3])
plt.plot(sol[3:6])
plt.plot(sol[6:])
# Out:
# [[373.00664452]
#  [ 78.48837209]
#  [ 19.43521595]
#  [359.55149502]
#  [146.51162791]
#  [ 38.12292359]
#  [378.23920266]
#  [109.88372093]
#  [ 24.66777409]]
# [[ 6000. -1000.     0. -1000.     0.     0.     0.     0.     0.]
#  [    0.     0.     0. -1000.     0.     0.  6000. -1000.     0.]
#  [    0. -1000.  6000.     0.     0. -1000.     0.     0.     0.]
#  [    0.     0.     0.     0.     0. -1000.     0. -1000.  6000.]
#  [-1000.  5000. -1000.     0.     0.     0.     0.     0.     0.]
#  [-1000.     0.     0.  5000. -1000.     0. -1000.     0.     0.]
#  [    0.     0. -1000.     0. -1000.  5000.     0.     0. -1000.]
#  [    0.     0.     0.     0. -1000.     0. -1000.  5000. -1000.]
#  [    0. -1000.     0. -1000.  4000. -1000.     0. -1000.     0.]]

# %%
import numpy as np
from numpy.linalg import inv
matrix=np.zeros((100,100))
gama=1000
area=10
x=10
n=np.zeros((100))
s=np.zeros((100))
e=np.zeros((100))
w=np.zeros((100))
for i in range(100):
    n[i]=10
for i in range(100):
    s[i]=10
for i in range(100):
    w[i]=450
for i in range(100):
    e[i]=3
for i in range(100):
    for j in range(100):
        if i==0 and j==0:
            matrix[i,j]=6*gama*area/x
        if i==0:
            matrix[i,1]=-gama*area/x
            matrix[i,10]=-gama*area/x
        if i==1:
            matrix[i,90]=6*gama*area/x
            matrix[i,80]=-gama*area/x
            matrix[i,91]=-gama*area/x
        if i==2:
            matrix[i,9]=6*gama*area/x
            matrix[i,8]=-gama*area/x
            matrix[i,19]=-gama*area/x
        if i==3:
            matrix[i,99]=6*gama*area/x
            matrix[i,89]=-gama*area/x
            matrix[i,98]=-gama*area/x
